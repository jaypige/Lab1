# %% [markdown]
# ## Matricule & noms : Jonathan Bukera, Jérôme Pigeon (1964463), Kaywan Sanjari (1989922)

# %% [markdown]
# ### <center> ELE8812 - Traitement et analyse d'images </center>
# <center> Travail practique No. 1 </center>
# <center>Hiver 2021 </center>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# Ce <a href="https://realpython.com/matlab-vs-python/"> lien</a> vous permettra de voir les différences fondamentales entre Python et Matlab. Ne passez pas forcement par les étapes d'installation.
# </div>

# %% [markdown]
# L’objet de ce travail est de mettre en pratique certains des traitements élémentaires dans le domaine spatial qui ont été présentés en cours, tout en permettant une familiarisation avec Python et ses outils de traitement d’images. Trois points seront abordés :
# 1. Les transformations géométriques
# 2. Le débruitage par filtrage dans le domaine spatial
# 3. L’amélioration d’images par manipulation d’histogramme et masque flou
#
# Les fonctions et les données à utiliser pour effectuer ce travail pratique se trouvent
# dans l’archive ZIP de ce TP disponible sur le site web du cours.
#
# **Pondération**
# - Transformations géométriques : 6 pts
# - Débruitage par filtrage spatial : 6 pts
# - Amélioration d’images : 6 pts
# - Qualités de la langue et du rapport : 2 pts
# - Total : 20 points
#
# **Date de remise**
# - Groupe 1: 14 février 23h59
# - Groupe 2: 21 février 23h59
#
# ##  1. Transformations géométriques (6 pts)
#
# L’interpolation est un élément central de toute transformation géométrique d’image.
# L’objet de cette question est de mettre en œuvre une forme élémentaire d’interpolation et
# de l’utiliser dans une transformation géométrique particulièrement simple : le changement
# d’échelle d’une image à l’aide d’une interpolation par plus proche voisin.
# ![image.png](attachment:image.png)

# %% [markdown]
# <div class="alert alert-block alert-info">
#
#
# La cellule ci dessous effectue des <code>import</code> cela s'assimile a un<code>addpath</code> en matlab. Le but est d'amener des fonctions extérieures (packages) dans le notebook afin que Python les reconnaisse.
# <code> import package as pkg</code> permet de raccourcir le nom de ce dernier. Les fonctions contenues dans 'package' seront alors appelées ainsi <code>pkg.function()</code><br>
#
# Vous pouvez chercher sur google chacun des package appelés ci-dessous afin d'obtenir leur documentation.<br>
#
# N'oubliez pas de relancer cette cellule si jamais vous redemarrez le Kernel !!
# </div>

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from matplotlib.pyplot import imread
# %matplotlib inline
import cv2
import numpy as np
plt.rcParams["figure.figsize"] = (12, 10)

# %% [markdown]
# ### 1.1. Fonction de changement d’échelle (3 pts)
# <div class="alert alert-block alert-warning">
# Développez une fonction définie comme suit. <br>
#
# - Indiquez la manière dont vous définissez les coordonnées de l’origine de chaque pixel d’une image (ex : au centre du pixel, dans le coin supérieur gauche …)
#
# - Décrivez chacune des étapes vous permettant de passer de l’image im à l’image ims.
#
# <b>Remarque</b> : Dans la fonction mae_ppv que vous développerez, vous ne devez pas utiliser
# les fonctions d’interpolation existantes. Par contre, vous pouvez vous inspirer de la fonction mae_bil.m qui implémente une interpolation bilinéaire.
#     </div>

# %%
# Inscrivez votre code ici
# Compléter la fonction suivante faisant de l'interpolation par plus proche voisin.
def mae_ppv(im, sc):
    """ Interpolation par plus proche voisin d'une image im.
    im (nd.array): Image à interpoler.
    sc (float): Facteur d'échelle.
    
    Return:
        nd.array: Image interporlée.
    """
    if sc <= 0 :
        display('scale : le parametre d echelle doit etre > 0')
        return
    
    #pour assuer que l'image est de 2 dimensions
    if np.ndim(im) != 2 :
        display('Image doit avoir 2 dimensions')
        return
    
    #Les dimmensions de l'image (M x N pixels)
    M, N = im.shape 

    
    #Les dimensions de la nouvelle image auquel on multiplie par un scale
    Ms, Ns = [round(M * sc), round(N * sc)]   
 
    #on crée un tableau vide (remplie de 0)
    ims = np.zeros((Ms,Ns))
    
    #On remplace chaque pixel de l'image original par son voisin (valeur la plus proche)
    #on insére cette valeur dans le tableau vide
    for i in range(Ms):
        for j in range(Ns):
            ims[i,j] = im[round(i/sc),round(j/sc)]
        
        
    
   
    return ims

# %%
def mae_bil(im, sc):
    """ Interpolation bilinéaire d'une image im.
    im (nd.array): Image à interpoler.
    sc (float): Facteur d'échelle.
    
    Return:
        nd.array: Image interporlée.
    """
    
    if sc <= 0 :
        display('scale : le parametre d echelle doit etre > 0')
        return
    

    if np.ndim(im) != 2 :
        display('Image doit avoir 2 dimensions')
        return

    M, N = im.shape

    # Nouvelles dimensions de l'image
    Ms, Ns = [round(M * sc), round(N * sc)]

    xs = np.linspace(1, Ms, Ms)
    ys = np.linspace(1, Ns, Ns)

    xsp = xs * M / Ms
    ysp = ys * N / Ns
    
    # Ajouter un pixel autour car il faut interpoler les pixels sur les bords
    Ap = np.pad(im, 1, 'symmetric')
    
    # Extraire les nouvelles coordonnées de l'image
    xisp = np.floor(xs * M / Ms).astype(int)
    yisp = np.floor(ys * N / Ns).astype(int)
    
    [Xsp, Ysp] = np.meshgrid(xsp,ysp)
    Xsp = np.transpose(Xsp)
    Ysp = np.transpose(Ysp)

    Xfsp = Xsp - np.floor(Xsp) # Coefficients pour l'interpolation
    Yfsp = Ysp - np.floor(Ysp)  

    # Interpolation bilinéaire
    ims = (1 - Xfsp) * (1 - Yfsp) * Ap[xisp, :][:, yisp] + \
          Xfsp * (1-Yfsp) * Ap[xisp + 1, :][:, yisp] + \
          (1 - Xfsp) * Yfsp * Ap[xisp, :][:, yisp + 1] + \
          Xfsp * Yfsp * Ap[xisp + 1, :][:, yisp + 1]
    
    return ims

# %% [markdown]
# ### 1.2. Effet de l’interpolation (3 pts)
# <div class="alert alert-block alert-warning">
#
# - Pour mettre en évidence l’effet de l’interpolation, utilisez la fonction que vous avez
# développée pour changer l’échelle de l’image Barbara.tif d’un facteur α
# inférieur à 1. Utilisez ensuite la même fonction et un facteur de 1/ α pour la ramener
# l’image transformée à son échelle initiale.
#   </div>

# %%
# Inscrivez votre code ici

oldIm = imread('Barbara.tif')
sc = 0.5
reSc = 1/sc

#on utilise l'interpolation par voisin pour chacune des deux images
newIm = mae_ppv(oldIm,sc)
reIm = mae_ppv(newIm,reSc)

#on affiche l'image originale
plt.subplot(1,3,1)
plt.imshow(oldIm, cmap = 'gray')
plt.title('Image originale')

#on affiche l'image transformée
plt.subplot(1,3,2)
plt.imshow(newIm, cmap = 'gray')
plt.title('Image transformée par un facteur scale 0.5')
plt.show()

#on affiche l'image transformée à son échelle initiale
plt.subplot(1,3,3)
plt.imshow(reIm, cmap = 'gray')
plt.title('Image transformée à son échelle initiale')
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
#
# - Effectuez les mêmes opérations avec la fonction mae_bil,
# qui utilise une interpolation bilinéaire.
#   </div>

# %%
# Inscrivez votre code ici
 # Inscrivez votre code ici
    
#même fonction que la question précédente mais avec l'interpolation bilinéaire    
oldIm2 = imread('Barbara.tif')
sc = 0.5
reSc = 1/sc

newIm2 = mae_bil(oldIm2,sc)
reIm2 = mae_bil(newIm2,reSc)

plt.subplot(1,3,1)
plt.imshow(oldIm2, cmap = 'gray')
plt.title('Image originale')

plt.subplot(1,3,2)
plt.imshow(newIm2, cmap = 'gray')
plt.title('Image transformée par un facteur scale 0.5')
plt.show()

plt.subplot(1,3,3)
plt.imshow(reIm2, cmap = 'gray')
plt.title('Image transformée à son échelle initiale')
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# - Qu’observez-vous ? Est-ce que les deux schémas d’interpolation permettent de
# reproduire fidèlement l’image originale ? À quoi sont dues les différences
# observées ? Pour répondre à cette question, vous pouvez calculer l’erreur
# quadratique moyenne entre les images.
#
# \begin{equation*}
# \Delta Q = \frac 1 n  \sum_{i,j}\left( I \left( i,j \right) - I' \left( i,j \right) \right)^2
# \end{equation*}
#
#
# Où n est le nombre de pixel dans l’image, 𝐼(𝑖,𝑗) est un pixel de l’image original et
# 𝐼’(𝑖,𝑗) est le pixel correspondant dans l’image transformée. Vous pouvez aussi
# observer l’histogramme des différences d’intensité entre les images.
#
#  </div>

# %%
# Inscrivez votre code ici
M, N = oldIm.shape
n = M*N
error = 0
for i in range(M):
    for j in range(N):
        error += (oldIm[i,j]-reIm[i,j])**2
        
TrueError =(1/n)*error
print('erreur = ', TrueError)
# Out:
# erreur =  447.2376237188615

# %% [markdown]
# <div class="alert alert-block alert-success">
# Non. Dans un premier temps, l'interpolation avec un facteur scale inférieur à 1 nous donne une image qui est moins précise à celle originale. Ceci s'explique par le fait qu'on perd de l'information en diminuant la taille de l'image et en négligeant les pixels les plus loins de la moyenne.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# - Quels artefacts (défauts) observez-vous dans les images réduites et reconstruites ?
#     </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# Les motifs rayés ne sont plus aussi claires, car c'est dans les petits détails et les parties de l'image qui sont non monochrome (différents motifs) qui sont le plus endomagé lorsqu'on réduit l'image. Ensuite, lorsqu'on la remet à sa taille original on agrandit les imperfections et elles prennent plus d'importance dans l'image.

# %% [markdown]
# ## 2. Débruitage par filtrage spatial (6 pts)
# <div class="alert alert-block alert-warning">
#
#
# Le fichier IRM_genou.tif de l’archive TP1.zip contient l’image d’un genou obtenue
# en imagerie par résonance magnétique nucléaire (IRM). Cette image est dégradée par un
# bruit relativement important. Le but de cette question est de mettre en œuvre et de comparer
# plusieurs filtres spatiaux, linéaires ou non. Développez et mettez en œuvre les filtres
# suivants :
#
# - Moyennage simple sur un masque carré de côté 3, 5 ou 7 pixels.
# - Moyennage pondéré de type gaussien sur un masque carré de côté 3, 5 ou 7 pixels.
# - Filtrage médian sur un masque carré de côté 3, 5 ou 7 pixels.
#
# La librairie OpenCV vous permet d'appliquer ces filtres (voir [documentation](https://docs.opencv.org/master/d4/d13/tutorial_py_filtering.html)). L’image filtrée doit être de même type et avoir la même taille que l’image de départ.
# Comparez empiriquement les résultats, en vous basant notamment sur le bruit résiduel, sur
# la netteté des contours des images filtrées et sur l’erreur quadratique moyenne. Vous
# pouvez au besoin vous appuyer sur leur histogramme. Le bruit résiduel Ο(𝑥, 𝑦) peut être
# calculé en soustrayant l’image filtrée 𝐼′(𝑥, 𝑦) à l’image originale 𝐼(𝑥, 𝑦).
#
# \begin{equation*}
# Ο(𝑥, 𝑦) = |𝐼(𝑥, 𝑦) − 𝐼′(𝑥, 𝑦)|
# \end{equation*}
#
#
# Discutez de l’effet du type de filtre (moyenne simple, moyenne pondérée, médian) et de la
# taille du filtre (3, 5, ou 7 pixels) sur les résultats de débruitage.
#     </div>

# %%
# Inscrivez votre code ici

# Inscrivez votre code ici

#image originale
og_Im = imread('IRM_genou.tif')

#image après les trois filtres pour 3 pixels
moy_Im_3 = cv2.blur(og_Im, (3,3))
gauss_Im_3 = cv2.GaussianBlur(og_Im, (3,3),0)
med_Im_3 = cv2.medianBlur(og_Im,3)

#image après les trois filtres pour 5 pixels
moy_Im_5 = cv2.blur(og_Im, (5,5))
gauss_Im_5 = cv2.GaussianBlur(og_Im, (5,5),0)
med_Im_5 = cv2.medianBlur(og_Im,5)

#image après les trois filtres pour 7 pixels
moy_Im_7 = cv2.blur(og_Im, (7,7))
gauss_Im_7 = cv2.GaussianBlur(og_Im, (7,7),0)
og_Im = cv2.convertScaleAbs(og_Im, alpha=255/65535.0)
med_Im_7 = cv2.medianBlur(og_Im,7)

#on affiche les 4 images (images originale + moyennage simple par 3, 5 et 7 pixels)
plt.subplot(6,4,1)
plt.imshow(og_Im, cmap = 'gray')
plt.title ('Image Originale')

plt.subplot(6,4,2)
plt.imshow(moy_Im_3, cmap = 'gray')
plt.title ('Filtre moyennage simple (3)')
plt.subplot(6,4,3)
plt.imshow(moy_Im_5, cmap = 'gray')
plt.title ('Filtre moyennage simple (5)')
plt.subplot(6,4,4)
plt.imshow(moy_Im_7, cmap = 'gray')
plt.title ('Filtre moyennage simple (7)')


# on affiche leur histogramme
plt.subplot(6,4,5)
#plt.title("Histogramme de l'image originale")
hist, bins = np.histogram(og_Im, 256, [0,256])
plt.plot(hist)
plt.subplot(6,4,6)
#plt.title("Histogramme filtre moyennage 3x3")
histr = cv2.calcHist([cv2.convertScaleAbs(moy_Im_3, alpha=255/65535.0)],[0],None,[256],[0,256])
plt.plot(histr)
plt.subplot(6,4,7)
#plt.title("Histogramme filtre moyennage 5x5")
histr = cv2.calcHist([cv2.convertScaleAbs(moy_Im_5, alpha=255/65535.0)],[0],None,[256],[0,256])
plt.plot(histr)
plt.subplot(6,4,8)
#plt.title("Histogramme filtre moyennage 7x7")
histr = cv2.calcHist([cv2.convertScaleAbs(moy_Im_7, alpha=255/65535.0)],[0],None,[256],[0,256])
plt.plot(histr)



#on affiche les 4 images (images originale + moyennage gauss par 3, 5 et 7 pixels)
plt.subplot(6,4,9)
plt.imshow(og_Im, cmap = 'gray')
plt.title ('Image Originale')

plt.subplot(6,4,10)
plt.imshow(gauss_Im_3, cmap = 'gray')
plt.title ('Filtre gauss (3)')
plt.subplot(6,4,11)
plt.imshow(gauss_Im_5, cmap = 'gray')
plt.title ('Filtre gauss (5)')
plt.subplot(6,4,12)
plt.imshow(gauss_Im_7, cmap = 'gray')
plt.title ('Filtre gauss (7)')

#On affiche leur histogramme
plt.subplot(6,4,13)
#plt.title("Histogramme de l'image originale")
histr = cv2.calcHist([og_Im],[0],None,[256],[0,256])
plt.plot(histr)

plt.subplot(6,4,14)
#plt.title("Histogramme filtre gauss 3x3")
histr = cv2.calcHist([cv2.convertScaleAbs(gauss_Im_3, alpha=255/65535.0)],[0],None,[256],[0,256])
plt.plot(histr)
plt.subplot(6,4,15)
#plt.title("Histogramme filtre gauss 5x5")
histr = cv2.calcHist([cv2.convertScaleAbs(gauss_Im_5, alpha=255/65535.0)],[0],None,[256],[0,256])
plt.plot(histr)
plt.subplot(6,4,16)
#plt.title("Histogramme filtre gauss 7x7")
histr = cv2.calcHist([cv2.convertScaleAbs(gauss_Im_7, alpha=255/65535.0)],[0],None,[256],[0,256])
plt.plot(histr)

#on affiche les 4 images (images originale + filtrage médiane par 3, 5 et 7 pixels)
plt.subplot(6,4,17)
plt.imshow(og_Im, cmap = 'gray')
plt.title ('Image Originale')

plt.subplot(6,4,18)
plt.imshow(med_Im_3, cmap = 'gray')
plt.title ('Filtre median (3)')
plt.subplot(6,4,19)
plt.imshow(med_Im_5, cmap = 'gray')
plt.title ('Filtre median (5)')
plt.subplot(6,4,20)
plt.imshow(med_Im_7, cmap = 'gray')
plt.title ('Filtre median (7)')

#on affiche leur histogramme
plt.subplot(6,4,21)
#plt.title("Histogramme de l'image originale")
histr = cv2.calcHist([og_Im],[0],None,[256],[0,256])
plt.plot(histr)


plt.subplot(6,4,22)
#plt.title("Histogramme filtre med 3x3")
histr = cv2.calcHist([cv2.convertScaleAbs(med_Im_3, alpha=255/65535.0)],[0],None,[256],[0,256])
plt.plot(histr)
plt.subplot(6,4,23)
#plt.title("Histogramme filtre med 5x5")
histr = cv2.calcHist([cv2.convertScaleAbs(med_Im_5, alpha=255/65535.0)],[0],None,[256],[0,256])
plt.plot(histr)
plt.subplot(6,4,24)
#plt.title("Histogramme filtre med 7x7")
histr = cv2.calcHist([med_Im_7],[0],None,[256],[0,256])
plt.plot(histr)

# %% [markdown]
# <div class="alert alert-block alert-success">
# Pour chacun des filtres, l'image devient plus lumineuse lorsque le nombre de pixels du masque carré augmente. On remarque qu'en augmentant la taille du filtre les images deviennent plus flou. Par contre, on réduit le bruit de l'image originale en comparant les différents niveaux des histogrammes pour chacun des filtres. On remarque que le filtre médian devient plus rapidement en augmentant la taille du filtre, ensuite vient le filtre median et finalement le filtre de Gauss. Ce dernier est celui qui garde le mieux la netteté de l'image.

# %% [markdown]
# ## 3. Amélioration d’images (6 pts)
#
# Le fichier Lune.tif contient une image de la lune de qualité médiocre, tant du point de
# vue de la distribution des niveaux de gris que de la netteté. Le but de cette question est
# donc d’appliquer une succession de traitements pour améliorer la qualité de cette image.
#
# ### 3.1. Transformations portant sur l’intensité (2 pts)
# <div class="alert alert-block alert-warning">
#
# En vous basant sur l’histogramme, effectuez une ou plusieurs transformations portant sur
# l’intensité de l’image pour en améliorer le contraste et l’aspect visuel. Quelques
# transformations que vous pouvez essayer pour améliorer le contraste sont :
#
# | Transformation | Paramètre(s) | Équation |
# | --- | --- | --- |
# | Inversion | NA | 1 – 𝑟 |
# |Gamma |   𝛾 < 1 si sous-exposé <br/> 𝛾 > 1 si surexposé | 𝑟<sup>𝛾</sup> |
# | Logarithme | NA | ln(1 + 𝑟) /ln(2) |
# | Exponentielle | NA | 𝑒<sup>𝑟𝑙𝑛(2)</sup> − 1|
#
# <center> ** r correspond à la valeur d’un pixel dans l’image </center>
#
# <b>Note</b> : Il n’est pas conseillé de procéder à l’égalisation de l’histogramme à cette étape-ci.
# Expliquez votre choix de transformation que vous avez utilisé pour améliorer l’aspect
# visuel de l’image.
#
# </div>

# %%
# Inscrivez votre code ici

luneIm = cv2.imread("Lune.tif", cv2.IMREAD_GRAYSCALE)

#Dimensions de l'image de la lune
M,N = luneIm.shape
print(M,N)

#on crée l'histogramme de cette image
histr = cv2.calcHist([luneIm],[0],None,[256],[0,256])

#la transformation gamme
img = luneIm
gamma = 0.55
s = cv2.pow(img/255, gamma)
print(s.shape)
s = cv2.convertScaleAbs(s, alpha=255)

# On affiche l'image originale et son histogramme
plt.subplot(2,2,1)
plt.title("Image originale")
plt.imshow(img, cmap = 'gray')
plt.subplot(2,2,2)
plt.title("Histogramme de l'image originale")
plt.plot(histr)
plt.show()

#on affiche l'image corrigée par une transformation gamma et son histogramme
plt.subplot(2,2,3)
plt.title(f"Image corrigée Gamma {gamma}")
plt.imshow(s, cmap = 'gray')

plt.subplot(2,2,4)
plt.title("Histogramme de l'image corrigée")
histr = cv2.calcHist([s],[0],None,[256],[0,256])
plt.plot(histr)
plt.show()
# Out:
# 540 466
# (540, 466)

# %% [markdown]
# <div class="alert alert-block alert-success">
# Puisque l'on avait une image sous-exposée, il a été décidé d'appliquer la transformation gamma. La transformation exponentielle quant à elle donnait un résultat surexposé puisque l'on réduisait trop les ton noirs tout en augmentant drastiquement les tons clairs. La transformation inverse ne s'applique pas pour cette image étant donné que la lune sera inversé en couleur (sera plus foncé) et le fond sera blanc. Par la suite, la transformation logarithmique fut évité puisque les basses intensités de couleur deviendraient plus hautes, on perdrait ainsi les contrastes entres les intensités. <br>
#
# La fonction gamma permet d'avoir une correction plus douce sur l'ensemble du spectre des tons de gris. On peut voir sur l'histogramme que les tons plus clairs on été augmentés. Par contre on voit aussi que dans l'image corrigé, les interfaces entre l'arrière-plan et la lune ne sont pas agréable à regarder puisque le contraste entre les deux se fait de manière trop abrupte

# %% [markdown]
# ### 3.2. Affinage de l’image (2 pts)
# <div class="alert alert-block alert-warning">
#
#
# Appliquez à l’image obtenue à la question précédente un rehaussement par masquage flou
# généralisé (Unsharp Filter / Masking en anglais). Ce filtre de convolution est défini par
#
# <center> 𝐺 = 𝐹 + 𝑎 [ 𝐹 − ℎ<sub>𝑏</sub> ∗ 𝐹 ] = 𝐹 + 𝑎 [ 𝐹 − 𝐹′ ] </center>
#
# où F est l’image originale, G est l’image rehaussée, hb est un noyau de convolution agissant
# comme un filtre passe-bas, * est un produit de convolution, a est le coefficient de
# rehaussement et b contrôle la taille du filtre adoucisseur. Utilisez le filtre par moyennage
# pondéré de type Gaussien développé à la question précédente pour calculer l’image floue
# 𝐹′ = ℎ<sub>𝑏</sub> ∗ 𝐹.
#
# Faites varier la taille du filtre adoucisseur et le coefficient de rehaussement. Qu’observezvous ? Décrivez l’effet de ces paramètres sur l’image rehaussée.
# </div>

# %%
# Inscrivez votre code ici



#luneIm = imread('Lune.tif')
s = luneIm
gauss_Im = cv2.GaussianBlur(s, (3,3),0)


#Filtre de convolution
f = s  + 1.4*(s - gauss_Im+50) 
plt.subplot(2,2,1)
plt.title("image originale")
plt.imshow(luneIm, cmap = 'gray')

#histogramme de l'image originale 
histr = cv2.calcHist([luneIm],[0],None,[256],[0,256])
plt.subplot(2,2,2)
plt.title("Histogramme de l'image originale")
plt.plot(histr)
plt.show()


plt.subplot(2,2,3)
plt.title("image corrigée")
plt.imshow(f, cmap = 'gray')

#histogramme de l'image corrigée par le filtre
histr = cv2.calcHist([cv2.convertScaleAbs(f)],[0],None,[256],[0,256])
plt.subplot(2,2,4)
plt.title("Histogramme de l'image corrigée")
plt.plot(histr)
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-success">
# En augmentant le coefficient de rehaussement, l'intensite de l'image augmente. Par exemple, lorsque ce coefficient est à 1.4, les 176001 pixels se retrouvent à une intensité de 60. En augmentant ce coefficient à 2.4, ces 176001 pixels sont d'une intensité d'environ 125. À l'inverse, en diminant ce coeffient à 0.4, les 176001 pixels ont une intensité d'autour de 25.

# %% [markdown]
# ### 3.3. Égalisation d’histogramme (2 pts)
# <div class="alert alert-block alert-warning">
#
#
# Appliquez une égalisation d’histogramme à une image visuellement satisfaisante obtenue à la question précédente. Qu’observez-vous ? Expliquez. Comparez au résultat obtenu si vous appliquez l’égalisation d’histogramme à l’image de la Lune originale sans transformer son intensité et sans la rehausser par masquage flou. Pourquoi les résultats sont-ils différents ? Vous pouvez utiliser la fonction <code>equalize_histogram(img)</code> et <code>plt.hist</code> de matplotlib.
# </div>

# %%
def equalize_histogram(img):
    # Normaliser l'image de 0 à 255
    img = ((img - img.min()) / (img.max() - img.min()) * 255).astype('uint8')
    hist, bins = np.histogram(img, 256, [0,256])
    T = np.cumsum(hist) # Somme cumulée
    T = (T - T.min()) / (T.max() - T.min()) # Normalisation entre 0 et 1
    return (255 * T[img]).astype('uint8')

# %%
# Inscrivez votre code ici

#on égalise les deux images
luneIm_eq = equalize_histogram(luneIm)
f_eq = equalize_histogram(f)

#histogramme de l'image corrigée après égalisation
plt.subplot(3,2,1)
plt.title('Image corrigée après égalisation du histrogramme')
plt.imshow(f_eq, cmap = 'gray')
histr = cv2.calcHist([f_eq],[0],None,[256],[0,256]) 
plt.subplot(3,2,2)
plt.plot(histr)


#histogramme de l'image originale
plt.subplot(3,2,3)
plt.title('Image originale')
plt.imshow(luneIm_eq, cmap = 'gray')
histr = cv2.calcHist([luneIm_eq],[0],None,[256],[0,256])
plt.subplot(3,2,4)
plt.plot(histr)
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-success">
# Il est possible de voir que l'image corrigée se trouve dans les tons très clairs et qu'il n'est pas possible de voir les différentes nuances des couleurs de l'image. On ne peut pas discerner les différents tons de blancs et de gris. En ayant fait une première transformation, nous avons trouvé une image avec des tons qui permettait un bon contraste entre les différentes régions d'intérêts. Les pixels noirs sont devenu plus clair (environ une valeur de 42 pour l'arrière plan).En ce qui a trait à la lune non modifié, la majorité de ses pixels sont noirs et ils restent noir après l'égalisation. Le spectre des pixels bougent pour être le plus possible représenté sur le spectre. En ce qui a trait à l'image originale, il est possible de voir que celle-ci est plus balancée que celle corrigée. <br>
